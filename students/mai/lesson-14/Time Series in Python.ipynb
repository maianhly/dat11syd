# %%
# !pip install pystan
# Out:
# Requirement already satisfied: pystan in /Users/ianhansel/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from pystan)
# Requirement already satisfied: numpy>=1.7 in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from pystan)

# %%
# !pip install fbprophet
# Out:
# Requirement already satisfied: fbprophet in /Users/ianhansel/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: pystan>=2.14 in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from fbprophet)
# Requirement already satisfied: numpy in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from fbprophet)
# Requirement already satisfied: matplotlib in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from fbprophet)
# Requirement already satisfied: pandas>=0.18.1 in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from fbprophet)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from pystan>=2.14->fbprophet)
# Requirement already satisfied: six>=1.10 in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: python-dateutil in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: pytz in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: cycler>=0.10 in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from matplotlib->fbprophet)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /Users/ianhansel/anaconda3/lib/python3.6/site-packages (from matplotlib->fbprophet)

# %%
# Import libraries
import pandas as pd
import numpy as np
from fbprophet import Prophet

# %%
# Read in data
df = pd.read_csv('../../../data/example_wp_peyton_manning.csv')
df['y'] = np.log(df['y'])
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
# Fit a time series model
m = Prophet()
m.fit(df);
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /usr/local/lib/python3.5/dist-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
# Predict future time series
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
# Attach predicted values - yhat
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.205908    7.502417    8.971295
# 3266 2017-01-16  8.530913    7.786620    9.259517
# 3267 2017-01-17  8.318289    7.573944    9.047677
# 3268 2017-01-18  8.150906    7.408766    8.914119
# 3269 2017-01-19  8.162788    7.403660    8.882923

# %%
# Plot the forecasted values
from matplotlib import pyplot as plt
# %matplotlib inline

m.plot(forecast);

# %%
# Time Series Decomposition
m.plot_components(forecast);
