# %% [markdown]
# # ## General Assembly DAT11 Sydney - 26th Feb 2018 ##
#
# ## Visualising Data with Python

# %%
# Load the Iris dataset from CSV URL
# 1. Import the required libraries
import numpy as np
import pandas as pd
import urllib
import xlrd

# Display the plots in the notebook with the following command
# %matplotlib inline
# Import the graphing libraries we will use
import matplotlib.pyplot as plt

# %% [markdown]
# ### Visualising data in Python
# This Section will deal with visualising data in Python. We will cover different graph types and how to interpret them.

# %%
# Read data from a csv
iris_data = pd.read_csv('../../../../data/iris.csv')
iris_data.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
#Remove the first 'Unnamed' Column:
iris_data = iris_data.iloc[:,1:6]
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data[['sepal_width']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f48195800f0>]],
#       dtype=object)

# %%
# Install another Python library using pip
#! pip3 install seaborn # Already installed - don't need to do this!

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
iris_data.loc[iris_data['species'] == 'setosa', 'sepal_width'].hist()
plt.xlabel("Sepal width (cm)")
plt.ylabel("Count")
plt.show()

# %%
# Draw a Scatterplot showing sepal width and length
sns.lmplot(x='sepal_width', y="sepal_length", hue="species", data=iris_data, fit_reg=True)
#iris_data.plot(kind='scatter', x='sepal_width', y='sepal_length');

# %%
sns.jointplot(x="sepal_width", y="sepal_length", data=iris_data);

# %%
sns.pairplot(iris_data);

# %%
sns.pairplot(iris_data, hue='species');

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates (iris_data, 'species')

# %% [markdown]
# ### Plotly
# A nice open source library for interactive visualisations

# %%
# To run any command at the system shell, simply prefix it with !
# pip won't work from inside python without it
#!pip install plotly --upgrade

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 2.4.1

# %%
import plotly
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)

plotly.offline.iplot({
    "data": [Scatter(x=[1, 2, 3, 4], y=[4, 3, 2, 1])],
    "layout": Layout(title="hello world")
})
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="3b9f4aa5-3de1-40c9-a6aa-3dfeee1040a1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3b9f4aa5-3de1-40c9-a6aa-3dfeee1040a1", [{"type": "scatter", "y": [4, 3, 2, 1], "x": [1, 2, 3, 4]}], {"title": "hello world"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
import plotly as py
import plotly.figure_factory as ff
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
plotly.offline.iplot(table, filename='jupyter/table1')
# Out:
# <div id="d9f1f91a-3848-4559-97ed-af0c616f9de6" style="height: 710px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d9f1f91a-3848-4559-97ed-af0c616f9de6", [{"hoverinfo": "none", "z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5]], "opacity": 0.75, "showscale": false, "colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "type": "heatmap"}], {"margin": {"r": 0, "l": 0, "b": 0, "t": 0}, "annotations": [{"xanchor": "left", "y": 0, "align": "left", "x": -0.45, "yref": "y1", "text": "<b>School</b>", "xref": "x1", "showarrow": false, "font": {"color": "#ffffff"}}, {"xanchor": "left", "y": 0, "align": "left", "x": 0.55, "yref": "y1", "text": "<b>Women</b>", "xref": "x1", "showarrow": false, "font": {"color": "#ffffff"}}, {"xanchor": "left", "y": 0, "align": "left", "x": 1.55, "yref": "y1", "text": "<b>Men</b>", "xref": "x1", "showarrow": false, "font": {"color": "#ffffff"}}, {"xanchor": "left", "y": 0, "align": "left", "x": 2.55, "yref": "y1", "text": "<b>Gap</b>", "xref": "x1", "showarrow": false, "font": {"color": "#ffffff"}}, {"xanchor": "left", "y": 1, "align": "left", "x": -0.45, "yref": "y1", "text": "MIT", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 1, "align": "left", "x": 0.55, "yref": "y1", "text": "94", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 1, "align": "left", "x": 1.55, "yref": "y1", "text": "152", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 1, "align": "left", "x": 2.55, "yref": "y1", "text": "58", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 2, "align": "left", "x": -0.45, "yref": "y1", "text": "Stanford", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 2, "align": "left", "x": 0.55, "yref": "y1", "text": "96", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 2, "align": "left", "x": 1.55, "yref": "y1", "text": "151", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 2, "align": "left", "x": 2.55, "yref": "y1", "text": "55", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 3, "align": "left", "x": -0.45, "yref": "y1", "text": "Harvard", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 3, "align": "left", "x": 0.55, "yref": "y1", "text": "112", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 3, "align": "left", "x": 1.55, "yref": "y1", "text": "165", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 3, "align": "left", "x": 2.55, "yref": "y1", "text": "53", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 4, "align": "left", "x": -0.45, "yref": "y1", "text": "U.Penn", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 4, "align": "left", "x": 0.55, "yref": "y1", "text": "92", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 4, "align": "left", "x": 1.55, "yref": "y1", "text": "141", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y": 4, "align": "left", "x": 2.55, "yref": "y1", "text": "49", "xref": "x1", "showarrow": false, "font": {"color": "#000000"}}, {"xanchor": "left", "y" ...

# %%
import plotly.plotly as py
from plotly.graph_objs import *

data = [Bar(x=df.School,
            y=df.Gap)]

plotly.offline.iplot(data, filename='jupyter/basic_bar')
# Out:
# <div id="3070c00b-0dfe-409d-a327-221c63cd9283" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3070c00b-0dfe-409d-a327-221c63cd9283", [{"type": "bar", "y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace_women = Bar(x=df.School,
                  y=df.Women,
                  name='Women',
                  marker=dict(color='#ffcdd2'))

trace_men = Bar(x=df.School,
                y=df.Men,
                name='Men',
                marker=dict(color='#A2D5F2'))

trace_gap = Bar(x=df.School,
                y=df.Gap,
                name='Gap',
                marker=dict(color='#59606D'))

data = [trace_women, trace_men, trace_gap]
layout = Layout(title="Average Earnings for Graduates",
                xaxis=dict(title='School'),
                yaxis=dict(title='Salary (in thousands)'))
fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, filename='jupyter/styled_bar')
# Out:
# <div id="44ef7577-7cab-448e-8a81-7ed661300aa8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("44ef7577-7cab-448e-8a81-7ed661300aa8", [{"marker": {"color": "#ffcdd2"}, "name": "Women", "type": "bar", "y": [94, 96, 112, 92, 90, 78, 94, 76, 79, 86, 93, 84, 67, 73, 80, 62, 72, 71, 68, 64, 72], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}, {"marker": {"color": "#A2D5F2"}, "name": "Men", "type": "bar", "y": [152, 151, 165, 141, 137, 118, 131, 112, 114, 119, 124, 114, 94, 100, 107, 84, 92, 88, 82, 78, 81], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}, {"marker": {"color": "#59606D"}, "name": "Gap", "type": "bar", "y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}], {"xaxis": {"title": "School"}, "title": "Average Earnings for Graduates", "yaxis": {"title": "Salary (in thousands)"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
# Scatter plot with heatmap
x = np.random.randn(2000)
y = np.random.randn(2000)
plotly.offline.iplot([Histogram2dContour(x=x, y=y, contours=Contours(coloring='heatmap')),
       Scatter(x=x, y=y, mode='markers', marker=Marker(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div id="525c45e0-8f12-4f4e-b702-d512e67dd95a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("525c45e0-8f12-4f4e-b702-d512e67dd95a", [{"contours": {"coloring": "heatmap"}, "type": "histogram2dcontour", "y": [0.7125474509041066, -2.7102691121698372, 0.40033900548992984, -1.2584492832934775, 1.9612514872256024, 0.021762749540211932, -0.018581790736405052, -0.8636675363631019, 1.4753606258300076, 0.036707814041707566, -0.23946831494275256, -1.3909440881531971, -1.7062098689129441, -2.026288873012863, 0.14061238108898402, -1.582910905577555, 1.0726238671694162, 0.5130352107362264, 0.19263161115474617, 0.4195085596551603, 1.1933388222344399, -0.7697388780804458, -1.0086119193513277, -1.4706536083440398, 0.3647713772050216, -1.9106894435317436, 0.538447802851559, -1.0670013866276182, 0.31555603018937145, 1.1313454090279345, -0.3869700919606984, -0.7119383745992888, 1.3228460907626944, 0.8330594310618777, 0.18456637440890566, 0.685589294379011, 0.06230600497948129, 0.4664643241453705, -0.7122036574256394, 0.1619812217934519, 1.4106565465738545, 0.5851553161559988, -1.719470171358472, 0.033250424759758826, -0.6824621526635509, 0.6820539213295718, -1.5343976350640716, -0.7122853965391849, -1.041663563097873, -0.7751669184448553, -0.1327698427132305, 0.34926849433286017, 0.1942501504202249, 0.797723640376366, 0.16030830716015812, -0.7958882314264988, -2.1290400318928224, 0.6413318265952892, -0.6298740537870888, -1.6390438416451627, 0.08304304783018905, -0.10415189528136368, -0.0880633326607868, -0.5723981085935489, -0.08127865334681604, -0.12251795360041824, -0.24940505479786768, -1.3975625223575536, -0.4731604249773, 0.07127716178917964, -0.8140099467468654, -0.042331742228354396, -0.036136878615048176, -1.1074072068111707, 1.8319357221738743, -0.3609481380155886, -0.024130711915752518, -0.2488745170786986, 0.3187297022462735, 1.292572870681639, 0.026744951606564052, -0.1463748030277958, -0.22005018473356863, 0.6114927690773688, 0.17188683873212485, 2.216581578785879, -0.01788276565639373, 0.15522101346948144, -0.4382831877487851, -0.05014906766808727, -0.1622678991736019, 0.08601937437999917, 2.281682682048504, 0.0973925318619734, 0.727206568037938, -0.9423937412770304, -0.8609063896917449, -0.05676134154371477, -0.38167190638755244, 0.09949129256987652, -1.1385435651165825, -0.8271864254621347, -0.7599607662456022, -0.518402772829548, 1.7986722919138944, -0.14323696759743734, -1.5298258006458296, 1.5583313192220996, 1.1125899960690195, 0.7575067972644587, -0.528450767396096, 0.6446809566006589, 0.07206641301754264, 0.4129924828790073, -0.18998876637561965, -0.7348232196452078, 0.13994938044528574, -0.2921945928843572, -0.41088433698676347, -0.2280455828031374, 0.4521376082839229, 0.4375524578303948, 0.7727714908713298, 1.5847868366452549, 1.4872720447160055, 0.6322136606726344, 0.3919121945358457, -1.3100317309779392, 0.8601080668792, 0.4929072611687381, 0.7177785920547862, -0.6492956433976286, -0.6316254584773132, 2.3557935327398933, 1.6364503607805412, 1.3409460754362343, -0.5097953197126873, 0.06713704493831972, -0.6584719065152785, -0.6315350971865427, 1.5685380427551583, 0.9825466243389643, -0.9995773534130614, -1.9445564861893767, -0.19760382318993946, -0.10737107075174367, -1.5366947826224349, 0.08146125529695708, -0.5044695508250997, -0.8092807337866382, -0.7424935962988517, 0.46508583220740723, 3.2583346248757605, 1.289620636382836, 0.6361463694663602, -1.6724864247302007, -0.7480389386364559, 1.2419403630313954, 0.9608998422984626, -0.5263372894027438, -0.3970834905386791, 1.1125524263282995, -1.264316090188694, -1.9133595691919967, -0.24147419145633262, 0.003732941472197293, -0.7654359210265802, 0.0749845482000716, 1.4661832100274474, 0.3304063932588514, -0.9810736323769882, 0.08103040528224713, 1.2736656611901147, -1.6128923297933575,  ...

# %%
# Load airport data

df_airports = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df_airports.head()
# Out:
#   iata                            airport               city state country  \
# 0  ORD       Chicago O'Hare International            Chicago    IL     USA
# 1  ATL  William B Hartsfield-Atlanta Intl            Atlanta    GA     USA
# 2  DFW    Dallas-Fort Worth International  Dallas-Fort Worth    TX     USA
# 3  PHX   Phoenix Sky Harbor International            Phoenix    AZ     USA
# 4  DEN                        Denver Intl             Denver    CO     USA
#
#          lat        long    cnt
# 0  41.979595  -87.904464  25129
# 1  33.640444  -84.426944  21925
# 2  32.895951  -97.037200  20662
# 3  33.434167 -112.008056  17290
# 4  39.858408 -104.667002  13781

# %%
# Load flight path data

df_flight_paths = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_aa_flight_paths.csv')
df_flight_paths.head()
# Out:
#    start_lat  start_lon    end_lat     end_lon airline airport1 airport2  cnt
# 0  32.895951 -97.037200  35.040222 -106.609194      AA      DFW      ABQ  444
# 1  41.979595 -87.904464  30.194533  -97.669872      AA      ORD      AUS  166
# 2  32.895951 -97.037200  41.938874  -72.683228      AA      DFW      BDL  162
# 3  18.439417 -66.001833  41.938874  -72.683228      AA      SJU      BDL   56
# 4  32.895951 -97.037200  33.562943  -86.753550      AA      DFW      BHM  168

# %%
airports[0]
# Out:
# {'hoverinfo': 'text', 'lat': 0      41.979595
#  1      33.640444
#  2      32.895951
#  3      33.434167
#  4      39.858408
#  5      29.980472
#  6      37.619002
#  7      33.942536
#  8      28.428889
#  9      35.214011
#  10     40.788388
#  11     27.975472
#  12     40.692497
#  13     36.080361
#  14     39.871953
#  15     44.880547
#  16     47.448982
#  17     40.777243
#  18     41.785983
#  19     38.944532
#  20     32.733556
#  21     38.747687
#  22     42.212059
#  23     40.639751
#  24     25.793250
#  25     42.364348
#  26     38.695422
#  27     39.175402
#  28     33.675659
#  29     29.993389
#           ...
#  191    47.482002
#  192    32.333133
#  193    46.353639
#  194    37.953759
#  195    35.035268
#  196    46.374498
#  197    37.700970
#  198    42.748119
#  199    44.473004
#  200    48.311405
#  201    28.102750
#  202    29.179917
#  203    40.652363
#  204    46.842090
#  205    41.155722
#  206    41.594217
#  207    37.858306
#  208    38.373151
#  209    48.792750
#  210    37.624049
#  211    44.257408
#  212    36.385913
#  213    27.910763
#  214    33.988796
#  215    34.991472
#  216    44.865257
#  217    42.402959
#  218    43.908826
#  219    34.681499
#  220    45.807662
#  Name: lat, Length: 221, dtype: float64, 'locationmode': 'USA-states', 'lon': 0      -87.904464
#  1      -84.426944
#  2      -97.037200
#  3     -112.008056
#  4     -104.667002
#  5      -95.339722
#  6     -122.374843
#  7     -118.408074
#  8      -81.316028
#  9      -80.943126
#  10    -111.977773
#  11     -82.533250
#  12     -74.168661
#  13    -115.152333
#  14     -75.241141
#  15     -93.216922
#  16    -122.309313
#  17     -73.872609
#  18     -87.752424
#  19     -77.455810
#  20    -117.189657
#  21     -90.359990
#  22     -83.348836
#  23     -73.778926
#  24     -80.290556
#  25     -71.005179
#  26    -121.590767
#  27     -76.668198
#  28    -117.868223
#  29     -90.258028
#            ...
#  191   -111.370685
#  192    -88.751206
#  193    -87.395361
#  194   -107.908480
#  195    -85.203788
#  196   -117.015394
#  197   -113.098575
#  198    -73.802979
#  199    -73.150312
#  200   -114.255069
#  201    -80.645806
#  202    -81.058056
#  203    -75.440402
#  204    -92.193649
#  205   -104.811838
#  206   -109.065193
#  207    -80.399472
#  208    -81.593190
#  209   -122.537528
#  210   -118.837772
#  211    -88.519476
#  212    -92.548828
#  213    -82.687439
#  214    -98.491893
#  215    -78.880000
#  216    -91.485072
#  217    -90.709167
#  218    -92.497987
#  219    -90.348816
#  220   -108.542861
#  Name: long, Length: 221, dtype: float64, 'marker': {'color': 'rgb(255, 0, 0)',
#   'line': {'color': 'rgba(68, 68, 68, 0)', 'width': 3},
#   'size': 2}, 'mode': 'markers', 'text': 0                 Chicago O'Hare International
#  1            William B Hartsfield-Atlanta Intl
#  2              Dallas-Fort Worth International
#  3             Phoenix Sky Harbor International
#  4                                  Denver Intl
#  5                 George Bush Intercontinental
#  6                  San Francisco International
#  7                    Los Angeles International
#  8                        Orlando International
#  9              Charlotte/Douglas International
#  10                         Salt Lake City Intl
#  11                        Tampa International
#  12                                 Newark Intl
#  13                      McCarran International
#  14                           Philadelphia Intl
#  15                    Minneapolis-St Paul Intl
#  16                         Seattle-Tacoma Intl
#  17                                   LaGuardia
#  18                              Chicago Midway
#  19             Washington Dulles International
#  20          San Diego International-Lindbergh
#  21              Lambert-St Louis International
#  22           Detroit Metropolitan-Wayne County
#  23                         John F Kennedy Intl
#  24                         Miami International
#  25                        Gen Edw L Logan Intl
#  26                    Sacramento International
#  27          Baltimore-Washington International
#  28                       John Wayne /Orange Co
#  29                  New Orleans International
#                          ...
#  191                           Great Falls Intl
#  192                                       Key
#  193                   Marquette County Airport
#  194                         Telluride Regional
#  195                                    Lovell
#  196                  Lewiston-Nez Perce County
#  197                            Cedar City Muni
#  198                                 Albany Cty
#  199                   Burlington International
#  200                          Glacier Park Intl
#  201                   Melbourne International
#  202                Daytona Beach International
#  203                Lehigh Valley International
#  204                       Duluth International
#  205                                   Cheyenne
#  206             Rock Springs-Sweetwater County
#  207                          Greenbrier Valley
#  208                                     Yeager
#  209                            Bellingham Intl
#  210                           Mammoth Yosemite
#  211                  Outagamie County Regional
#  212                            Branson Airport
#  213    St. Petersburg-Clearwater International
#  214       Sheppard AFB/Wichita Falls Municipal
#  215                     Fayetteville Municipal
#  216                   Chippewa Valley Regional
#  217                          Dubuque Municipal
#  218                    Rochester International
#  219                   Tunica Municipal Airport
#  220                        Billings Logan Intl
#  Name: airport, Length: 221, dtype: object, 'type': 'scattergeo'}

# %%
# Mapping

airports = [ dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_airports['long'], # longitude column from airports
        lat = df_airports['lat'], # latitude column from airports
        hoverinfo = 'text',
        text = df_airports['airport'], # airport name from airports
        mode = 'markers',
        marker = dict(
            size=2,
            color='rgb(255, 0, 0)',
            line = dict(
                width=3,
                color='rgba(68, 68, 68, 0)'
            )
        ))]

flight_paths = []
for i in range( len( df_flight_paths ) ):
    flight_paths.append(
        dict(
            type = 'scattergeo',
            locationmode = 'USA-states',
            lon = [ df_flight_paths['start_lon'][i], df_flight_paths['end_lon'][i] ],
            lat = [ df_flight_paths['start_lat'][i], df_flight_paths['end_lat'][i] ],
            mode = 'lines',
            line = dict(
                width = 1,
                color = 'red',
            ),
            opacity = float(df_flight_paths['cnt'][i])/float(df_flight_paths['cnt'].max()),
        )
    )

layout = dict(
        title = 'Feb. 2011 American Airline flight paths<br>(Hover for airport names)',
        showlegend = False,
        height = 800,
        geo = dict(
            scope='north america',
            projection=dict( type='azimuthal equal area' ),
            showland = True,
            landcolor = 'rgb(243, 243, 243)',
            countrycolor = 'rgb(204, 204, 204)',
        ),
    )

fig = dict( data=flight_paths + airports, layout=layout )

plotly.offline.iplot(fig)
# Out:
# <div id="e4e6c721-187d-432b-9aca-7e7603d45c3b" style="height: 800px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e4e6c721-187d-432b-9aca-7e7603d45c3b", [{"line": {"color": "red", "width": 1}, "lon": [-97.0372, -106.6091944], "mode": "lines", "opacity": 0.48577680525164113, "lat": [32.89595056, 35.04022222], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-87.90446417, -97.66987194], "mode": "lines", "opacity": 0.18161925601750548, "lat": [41.979595, 30.19453278], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-97.0372, -72.68322833], "mode": "lines", "opacity": 0.1772428884026258, "lat": [32.89595056, 41.93887417], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-66.00183333, -72.68322833], "mode": "lines", "opacity": 0.061269146608315096, "lat": [18.43941667, 41.93887417], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-97.0372, -86.75354972], "mode": "lines", "opacity": 0.1838074398249453, "lat": [32.89595056, 33.56294306], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-80.29055556, -86.67818222], "mode": "lines", "opacity": 0.061269146608315096, "lat": [25.79325, 36.12447667], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-97.0372, -71.00517917], "mode": "lines", "opacity": 0.4617067833698031, "lat": [32.89595056, 42.3643475], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-80.29055556, -71.00517917], "mode": "lines", "opacity": 0.4288840262582057, "lat": [25.79325, 42.3643475], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-87.90446417, -71.00517917], "mode": "lines", "opacity": 0.47045951859956237, "lat": [41.979595, 42.3643475], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-66.00183333, -71.00517917], "mode": "lines", "opacity": 0.061269146608315096, "lat": [18.43941667, 42.3643475], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-64.97336111, -71.00517917], "mode": "lines", "opacity": 0.04814004376367615, "lat": [18.33730556, 42.3643475], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-80.29055556, -76.66819833], "mode": "lines", "opacity": 0.12253829321663019, "lat": [25.79325, 39.17540167], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-66.00183333, -76.66819833], "mode": "lines", "opacity": 0.061269146608315096, "lat": [18.43941667, 39.17540167], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-97.0372, -80.94312583], "mode": "lines", "opacity": 0.3938730853391685, "lat": [32.89595056, 35.21401111], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-97.0372, -104.70025], "mode": "lines", "opacity": 0.3041575492341357, "lat": [32.89595056, 38.80580556], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-97.0372, -84.219375], "mode": "lines", "opacity": 0.1137855579868709, "lat": [32.89595056, 39.90237583], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-97.0372, -77.03772222], "mode": "lines", "opacity": 0.6433260393873085, "lat": [32.89595056, 38.85208333], "locationmode": "USA-states", "type": "scattergeo"}, {"line": {"color": "red", "width": 1}, "lon": [-80.29055556, -104.6670019], "mode": "lines", "opacity": 0.1225382 ...
