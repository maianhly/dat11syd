# %% [markdown]
# # ## General Assembly DAT11 Sydney - 26th Feb 2018 ##
#
# ## Visualising Data with Python

# %%
# Load the Iris dataset from CSV URL
# 1. Import the required libraries
import numpy as np
import pandas as pd
import urllib
import xlrd

# Display the plots in the notebook with the following command
# %matplotlib inline
# Import the graphing libraries we will use
import matplotlib.pyplot as plt

# %% [markdown]
# ### Visualising data in Python
# This Section will deal with visualising data in Python. We will cover different graph types and how to interpret them.

# %%
# Read data from a csv
iris_data = pd.read_csv('../../../../data/iris.csv')
iris_data.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
#Remove the first 'Unnamed' Column:
iris_data = iris_data.iloc[:,1:6]
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data[['sepal_width']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f48195800f0>]],
#       dtype=object)

# %%
# Install another Python library using pip
#! pip3 install seaborn # Already installed - don't need to do this!

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
iris_data.loc[iris_data['species'] == 'setosa', 'sepal_width'].hist()
plt.xlabel("Sepal width (cm)")
plt.ylabel("Count")
plt.show()

# %%
# Draw a Scatterplot showing sepal width and length
sns.lmplot(x='sepal_width', y="sepal_length", hue="species", data=iris_data, fit_reg=True)
#iris_data.plot(kind='scatter', x='sepal_width', y='sepal_length');

# %%
sns.jointplot(x="sepal_width", y="sepal_length", data=iris_data);

# %%
sns.pairplot(iris_data);

# %%
sns.pairplot(iris_data, hue='species');

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates (iris_data, 'species')

# %% [markdown]
# ### Plotly
# A nice open source library for interactive visualisations

# %%
# To run any command at the system shell, simply prefix it with !
# pip won't work from inside python without it
#!pip install plotly --upgrade

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 2.4.1

# %%
import plotly
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)

plotly.offline.iplot({
    "data": [Scatter(x=[1, 2, 3, 4], y=[4, 3, 2, 1])],
    "layout": Layout(title="hello world")
})
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="6604bc6e-d910-4b6a-b4c3-ae004dd8648c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6604bc6e-d910-4b6a-b4c3-ae004dd8648c", [{"y": [4, 3, 2, 1], "x": [1, 2, 3, 4], "type": "scatter"}], {"title": "hello world"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
import plotly as py
import plotly.figure_factory as ff
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
plotly.offline.iplot(table, filename='jupyter/table1')
# Out:
# <div id="bf53f6d8-e8fd-4763-af36-215f39dcbcc8" style="height: 710px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bf53f6d8-e8fd-4763-af36-215f39dcbcc8", [{"showscale": false, "colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "opacity": 0.75, "type": "heatmap", "hoverinfo": "none", "z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5]]}], {"margin": {"r": 0, "l": 0, "t": 0, "b": 0}, "yaxis": {"tick0": 0.5, "showticklabels": false, "autorange": "reversed", "zeroline": false, "gridwidth": 2, "ticks": "", "dtick": 1}, "xaxis": {"tick0": -0.5, "showticklabels": false, "zeroline": false, "gridwidth": 2, "ticks": "", "dtick": 1}, "height": 710, "annotations": [{"xref": "x1", "showarrow": false, "x": -0.45, "font": {"color": "#ffffff"}, "text": "<b>School</b>", "y": 0, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 0.55, "font": {"color": "#ffffff"}, "text": "<b>Women</b>", "y": 0, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 1.55, "font": {"color": "#ffffff"}, "text": "<b>Men</b>", "y": 0, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 2.55, "font": {"color": "#ffffff"}, "text": "<b>Gap</b>", "y": 0, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": -0.45, "font": {"color": "#000000"}, "text": "MIT", "y": 1, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 0.55, "font": {"color": "#000000"}, "text": "94", "y": 1, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 1.55, "font": {"color": "#000000"}, "text": "152", "y": 1, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 2.55, "font": {"color": "#000000"}, "text": "58", "y": 1, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": -0.45, "font": {"color": "#000000"}, "text": "Stanford", "y": 2, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 0.55, "font": {"color": "#000000"}, "text": "96", "y": 2, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 1.55, "font": {"color": "#000000"}, "text": "151", "y": 2, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 2.55, "font": {"color": "#000000"}, "text": "55", "y": 2, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": -0.45, "font": {"color": "#000000"}, "text": "Harvard", "y": 3, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 0.55, "font": {"color": "#000000"}, "text": "112", "y": 3, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 1.55, "font": {"color": "#000000"}, "text": "165", "y": 3, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 2.55, "font": {"color": "#000000"}, "text": "53", "y": 3, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": -0.45, "font": {"color": "#000000"}, "text": "U.Penn", "y": 4, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 0.55, "font": {"color": "#000000"}, "text": "92", "y": 4, "align": "left", "yref": "y1", "xanchor": "left"}, {"xref": "x1", "showarrow": false, "x": 1.55, "font": {"color ...

# %%
import plotly.plotly as py
from plotly.graph_objs import *

data = [Bar(x=df.School,
            y=df.Gap)]

plotly.offline.iplot(data, filename='jupyter/basic_bar')
# Out:
# <div id="ef693cd0-a4e0-406e-98f0-9a3e6f4e4e63" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ef693cd0-a4e0-406e-98f0-9a3e6f4e4e63", [{"y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"], "type": "bar"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace_women = Bar(x=df.School,
                  y=df.Women,
                  name='Women',
                  marker=dict(color='#ffcdd2'))

trace_men = Bar(x=df.School,
                y=df.Men,
                name='Men',
                marker=dict(color='#A2D5F2'))

trace_gap = Bar(x=df.School,
                y=df.Gap,
                name='Gap',
                marker=dict(color='#59606D'))

data = [trace_women, trace_men, trace_gap]
layout = Layout(title="Average Earnings for Graduates",
                xaxis=dict(title='School'),
                yaxis=dict(title='Salary (in thousands)'))
fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, filename='jupyter/styled_bar')
# Out:
# <div id="bb72b83d-218d-4d78-b9b8-ce42239dc953" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bb72b83d-218d-4d78-b9b8-ce42239dc953", [{"marker": {"color": "#ffcdd2"}, "name": "Women", "y": [94, 96, 112, 92, 90, 78, 94, 76, 79, 86, 93, 84, 67, 73, 80, 62, 72, 71, 68, 64, 72], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"], "type": "bar"}, {"marker": {"color": "#A2D5F2"}, "name": "Men", "y": [152, 151, 165, 141, 137, 118, 131, 112, 114, 119, 124, 114, 94, 100, 107, 84, 92, 88, 82, 78, 81], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"], "type": "bar"}, {"marker": {"color": "#59606D"}, "name": "Gap", "y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"], "type": "bar"}], {"title": "Average Earnings for Graduates", "xaxis": {"title": "School"}, "yaxis": {"title": "Salary (in thousands)"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
# Scatter plot with heatmap
x = np.random.randn(2000)
y = np.random.randn(2000)
plotly.offline.iplot([Histogram2dContour(x=x, y=y, contours=Contours(coloring='heatmap')),
       Scatter(x=x, y=y, mode='markers', marker=Marker(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div id="a3a1b992-f820-487c-a501-a45e3e64d12e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a3a1b992-f820-487c-a501-a45e3e64d12e", [{"contours": {"coloring": "heatmap"}, "y": [1.510542116356626, 1.6352584440655653, 0.5167672498727655, 0.46753513642558164, -1.6861831646104877, -1.0047709884294607, 1.3855657350145956, -1.3877634942624602, -0.36732265753624244, 0.9388525789776686, 0.1113902562190156, -0.3342223932047027, -0.09176189989708478, 2.47806525073559, -0.4136598944353419, -1.263582052394757, 0.4493170707728386, -1.4970929792513659, 0.7696960519528193, -0.33974361477499765, 0.3513037118774282, -0.05341594911094079, -0.6588260432468819, -0.6325457808281636, -0.6812901524273459, 0.15959699551926357, -0.02551114847841762, 1.3705191099370575, 0.846765648231961, -0.7046984438712312, -0.31780536974483636, -0.6509840145926832, 0.4631555095093726, -2.9206034612533602, -0.7845223301175352, -1.3869123761914066, -1.4778453022663443, -0.30439946490395464, 0.1654537151189729, 0.123102401353848, -0.7164162234924404, -0.8607798539688388, -0.47396340694647493, -0.32158845766257865, -0.2869594249750893, 0.46298389803945, 0.6800357185253497, -0.7077358752819788, -0.6435951394533127, -0.27131515136471435, 1.0987723951407513, 1.1572726329604477, 1.2997523329617768, 0.7352915657350048, 0.5411934656522028, -1.2050735751636117, -2.0867658843155077, -0.28053698560949364, 0.013717409027
"locationmode": "USA-states", "lon": [-97.0372, -72.68322833], "line": {"color": "red", "width": 1}}, {"opacity": 0.061269146608315096, "type": "scattergeo", "mode": "lines", "lat": [18.43941667, 41.93887417], "locationmode": "USA-states", "lon": [-66.00183333, -72.68322833], "line": {"color": "red", "width": 1}}, {"opacity": 0.1838074398249453, "type": "scattergeo", "mode": "lines", "lat": [32.89595056, 33.56294306], "locationmode": "USA-states", "lon": [-97.0372, -86.75354972], "line": {"color": "red", "width": 1}}, {"opacity": 0.061269146608315096, "type": "scattergeo", "mode": "lines", "lat": [25.79325, 36.12447667], "locationmode": "USA-states", "lon": [-80.29055556, -86.67818222], "line": {"color": "red", "width": 1}}, {"opacity": 0.4617067833698031, "type": "scattergeo", "mode": "lines", "lat": [32.89595056, 42.3643475], "locationmode": "USA-states", "lon": [-97.0372, -71.00517917], "line": {"color": "red", "width": 1}}, {"opacity": 0.4288840262582057, "type": "scattergeo", "mode": "lines", "lat": [25.79325, 42.3643475], "locationmode": "USA-states", "lon": [-80.29055556, -71.00517917], "line": {"color": "red", "width": 1}}, {"opacity": 0.47045951859956237, "type": "scattergeo", "mode": "lines", "lat": [41.979595, 42.3643475], "locationmode": "USA-states", "lon": [-87.90446417, -71.00517917], "line": {"color": "red", "width": 1}}, {"opacity": 0.061269146608315096, "type": "scattergeo", "mode": "lines", "lat": [18.43941667, 42.3643475], "locationmode": "USA-states", "lon": [-66.00183333, -71.00517917], "line": {"color": "red", "width": 1}}, {"opacity": 0.04814004376367615, "type": "scattergeo", "mode": "lines", "lat": [18.33730556, 42.3643475], "locationmode": "USA-states", "lon": [-64.97336111, -71.00517917], "line": {"color": "red", "width": 1}}, {"opacity": 0.12253829321663019, "type": "scattergeo", "mode": "lines", "lat": [25.79325, 39.17540167], "locationmode": "USA-states", "lon": [-80.29055556, -76.66819833], "line": {"color": "red", "width": 1}}, {"opacity": 0.061269146608315096, "type": "scattergeo", "mode": "lines", "lat": [18.43941667, 39.17540167], "locationmode": "USA-states", "lon": [-66.00183333, -76.66819833], "line": {"color": "red", "width": 1}}, {"opacity": 0.3938730853391685, "type": "scattergeo", "mode": "lines", "lat": [32.89595056, 35.21401111], "locationmode": "USA-states", "lon": [-97.0372, -80.94312583], "line": {"color": "red", "width": 1}}, {"opacity": 0.3041575492341357, "type": "scattergeo", "mode": "lines", "lat": [32.89595056, 38.80580556], "locationmode": "USA-states", "lon": [-97.0372, -104.70025], "line": {"color": "red", "width": 1}}, {"opacity": 0.1137855579868709, "type": "scattergeo", "mode": "lines", "lat": [32.89595056, 39.90237583], "locationmode": "USA-states", "lon": [-97.0372, -84.219375], "line": {"color": "red", "width": 1}}, {"opacity": 0.6433260393873085, "type": "scattergeo", "mode": "lines", "lat": [32.89595056, 38.85208333], "locationmode": "USA-states", "lon": [-97.0372, -77.03772222], "line": {"color": "red", "width": 1}}, {"opacity": 0.12253829321663019, "type": "scattergeo", "mode": "lines", "lat": [25.79325, 39.85840806], "location ...
